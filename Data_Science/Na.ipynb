# %%
import pandas as pd

# %%
data = pd.read_csv("C:\\Users\\Mayan\\Downloads\\tic_dec90_00S__88_00S.csv\\tic_dec90_00S__88_00S.csv")
data
# Out:
# C:\Users\Mayan\AppData\Local\Temp\ipykernel_24552\3542855192.py:1: DtypeWarning: Columns (115) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("C:\\Users\\Mayan\\Downloads\\tic_dec90_00S__88_00S.csv\\tic_dec90_00S__88_00S.csv")
#          410306832  20190415  Unnamed: 2 Unnamed: 3  Unnamed: 4  \
# 0        410306834  20190415         NaN        NaN         NaN
# 1        410306837  20190415         NaN        NaN         NaN
# 2        410306833  20190415         NaN        NaN         NaN
# 3        410306838  20190415         NaN        NaN  009-000117
# 4        410306887  20190415         NaN        NaN  008-000069
# ...            ...       ...         ...        ...         ...
# 196795  1921978523  20190415         NaN        NaN         NaN
# 196796  1921980254  20190415         NaN        NaN         NaN
# 196797  1921980071  20190415         NaN        NaN         NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196800 entries, 0 to 196799
# Columns: 125 entries, 410306832 to 509917610
# dtypes: float64(102), int64(3), object(20)
# memory usage: 187.7+ MB

# %%
data.describe()
# Out:
#           410306832    20190415     Unnamed: 2  Unnamed: 6  \
# count  1.968000e+05    196800.0      32.000000         0.0
# mean   8.659635e+08  20190415.0   52400.750000         NaN
# std    7.044579e+08         0.0   31042.798359         NaN
# min    2.795350e+07  20190415.0    1007.000000         NaN
# 25%    3.947808e+08  20190415.0   30278.000000         NaN
# 50%    7.240766e+08  20190415.0   49060.000000         NaN
# 75%    1.003084e+09  20190415.0   75983.250000         NaN
# max    1.000264e+10  20190415.0  112355.000000         NaN
#
#        4612820611348441984    Unnamed: 9  Unnamed: 10  9.0651364108785408  \
# count         1.933880e+05  6.544000e+03          0.0       196800.000000
# mean          5.486267e+18  3.544628e+07          NaN          181.640594
# std           6.263030e+17  1.308934e+04          NaN          100.663761
# min           4.611686e+18  3.542380e+07          NaN            0.007422
# ...

# %%
data.dropna(axis=1, how='all', inplace=True) # Drop columns where all elements are NaN
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 data.dropna(axis=1, how='all', inplace=True) # Drop columns where all elements are NaN
#
# AttributeError: 'NoneType' object has no attribute 'dropna'
