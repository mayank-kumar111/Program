# %% [markdown]
#     pip install pymysql

# %%
import pymysql as sql

# %%
conn = sql.connect(user='root', password='', port=3306, host='localhost', database="dsml_mayank")
conn

# %%
show databases; # show tables; # show columns from table_name; it is a SQL command, not a Python command. You can run it in MySQL Workbench or any SQL client.
# Out:
#   Cell In[6], line 1
#     show databases;
#          ^
# SyntaxError: invalid syntax

# %%
cur = conn.cursor()
cur

# %%
cur.execute("show databases")
# Out:
# 6

# %%
cur.fetchall()
# Out:
# (('dsml_mayank',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('phpmyadmin',),
#  ('test',))

# %%
cur.execute("show tables")
cur.fetchall()
# Out:
# (('fees',), ('student',))

# %%
conn.close()

# %%
def connect_db():
    conn = sql.connect(user='root', password='', port=3306, host='localhost', database="dsml_mayank")
    cur = conn.cursor()
    return conn, cur

# %%
conn, cur = connect_db()

# %%
conn

# %%
cur

# %%
cur.execute("select * from student")
cur.fetchall()
# Out:
# ((101, 'Mayank', 23),
#  (102, 'Rohan', 25),
#  (103, 'Deep', 26),
#  (104, 'Gaurav', 26),
#  (105, 'Ram', None))

# %%
cur.execute("insert into student values(106, 'rajat', 25)")
# Out:
# 1

# %%
conn.commit()

# %%
conn.close()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 conn.close()
#
# File e:\App\Python\Lib\site-packages\pymysql\connections.py:431, in Connection.close(self)
#     422 """
#     423 Send the quit message and close the socket.
#     424
#    (...)    428 :raise Error: If the connection is already closed.
#     429 """
#     430 if self._closed:
# --> 431     raise err.Error("Already closed")
#     432 self._closed = True
#     433 if self._sock is None:
#
# Error: Already closed
