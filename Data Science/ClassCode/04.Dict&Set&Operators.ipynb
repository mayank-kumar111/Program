# %% [markdown]
# # Dict
#         Collection of key & value pairs
#         { }
#         ordered
#         mutable
#         keys nust be unique & immutable

# %%
print([i for i in dir(dict) if not i.startswith('__')])
# Out:
# ['clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']

# %%
data = {'name':'deep', 'age':26, 'address':'jaipur'}
data
# Out:
# {'name': 'deep', 'age': 26, 'address': 'jaipur'}

# %%
lst = [324,45,67,7,8]

# %%
lst[0]
# Out:
# 324

# %%
data
# Out:
# {'name': 'deep', 'age': 26, 'address': 'jaipur'}

# %%
data['name']
# Out:
# 'deep'

# %%
data['age']
# Out:
# 26

# %%
data['address']
# Out:
# 'jaipur'

# %%
data
# Out:
# {'name': 'deep', 'age': 26, 'address': 'jaipur'}

# %%
data['city']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 data['city']
#
# KeyError: 'city'

# %%
data['city'] = 'jaipur'

# %%
data
# Out:
# {'name': 'deep', 'age': 26, 'address': 'jaipur', 'city': 'jaipur'}

# %%
data
# Out:
# {'name': 'deep', 'age': 26, 'address': 'jaipur', 'city': 'jaipur'}

# %%
data['city'] = 'Ajmer'

# %%
data
# Out:
# {'name': 'deep', 'age': 26, 'address': 'jaipur', 'city': 'Ajmer'}

# %%
data
# Out:
# {'name': 'deep', 'age': 26, 'address': 'jaipur', 'city': 'Ajmer'}

# %%
data.keys()
# Out:
# dict_keys(['name', 'age', 'address', 'city'])

# %%
data.values()
# Out:
# dict_values(['deep', 26, 'jaipur', 'Ajmer'])

# %%
data
# Out:
# {'name': 'deep', 'age': 26, 'address': 'jaipur', 'city': 'Ajmer'}

# %%
data.items()
# Out:
# dict_items([('name', 'deep'), ('age', 26), ('address', 'jaipur'), ('city', 'Ajmer')])

# %%
data
# Out:
# {'name': 'deep', 'age': 26, 'address': 'jaipur', 'city': 'Ajmer'}

# %%
data['name']
# Out:
# 'deep'

# %%
data['state']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 data['state']
#
# KeyError: 'state'

# %%
data.get('name')
# Out:
# 'deep'

# %%
print(data.get('state'))
# Out:
# None

# %%
data
# Out:
# {'name': 'deep', 'age': 26, 'address': 'jaipur', 'city': 'Ajmer'}

# %%
data.update({'state':"raj", 'city':"jaipur", 'marks':45})

# %%
data
# Out:
# {'name': 'deep',
#  'age': 26,
#  'address': 'jaipur',
#  'city': 'jaipur',
#  'state': 'raj',
#  'marks': 45}

# %%
data.get('subject', "value not found")
# Out:
# 'value not found'

# %%
data
# Out:
# {'name': 'deep',
#  'age': 26,
#  'address': 'jaipur',
#  'city': 'jaipur',
#  'state': 'raj',
#  'marks': 45}

# %% [markdown]
#     pop
#     popitem

# %%
data
# Out:
# {'name': 'deep',
#  'age': 26,
#  'address': 'jaipur',
#  'city': 'jaipur',
#  'state': 'raj',
#  'marks': 45}

# %%
data.pop('age')
# Out:
# 26

# %%
data
# Out:
# {'name': 'deep',
#  'address': 'jaipur',
#  'city': 'jaipur',
#  'state': 'raj',
#  'marks': 45}

# %%
data.pop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 data.pop()
#
# TypeError: pop expected at least 1 argument, got 0

# %%
data.pop('age')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 data.pop('age')
#
# KeyError: 'age'

# %%
data.pop('age', "key not found")
# Out:
# 'key not found'

# %%
data
# Out:
# {'name': 'deep',
#  'address': 'jaipur',
#  'city': 'jaipur',
#  'state': 'raj',
#  'marks': 45}

# %%
data.popitem()
# Out:
# ('marks', 45)

# %%
data
# Out:
# {'name': 'deep', 'address': 'jaipur', 'city': 'jaipur', 'state': 'raj'}

# %%
data.popitem()
# Out:
# ('state', 'raj')

# %%
data
# Out:
# {'name': 'deep', 'address': 'jaipur', 'city': 'jaipur'}

# %% [markdown]
#     fromkeys
#     setdefault

# %%
dict.fromkeys()

# %%
dict.fromkeys?
# Out:
# Signature: dict.fromkeys(iterable, value=None, /)
# Docstring: Create a new dictionary with keys from iterable and values set to value.
# Type:      builtin_function_or_method

# %%
help(dict.fromkeys)
# Out:
# Help on built-in function fromkeys:
#
# fromkeys(iterable, value=None, /) method of builtins.type instance
#     Create a new dictionary with keys from iterable and values set to value.

# %%
dict.fromkeys([10,20,30,40,50])
# Out:
# {10: None, 20: None, 30: None, 40: None, 50: None}

# %%
dict.fromkeys([10,20,30,40,50], ['hello', 'hii'])
# Out:
# {10: ['hello', 'hii'],
#  20: ['hello', 'hii'],
#  30: ['hello', 'hii'],
#  40: ['hello', 'hii'],
#  50: ['hello', 'hii']}

# %%
data = {'name':'aman', 'age':25, 'address':'jaipur'}

# %%
data
# Out:
# {'name': 'aman', 'age': 25, 'address': 'jaipur'}

# %%
data.setdefault('name')
# Out:
# 'aman'

# %%
data.setdefault('city')

# %%
data
# Out:
# {'name': 'aman', 'age': 25, 'address': 'jaipur', 'city': None}

# %%
data.popitem()
# Out:
# ('city', None)

# %%
data
# Out:
# {'name': 'aman', 'age': 25, 'address': 'jaipur'}

# %%
data.setdefault('city', 'jaipur')
# Out:
# 'jaipur'

# %%
data
# Out:
# {'name': 'aman', 'age': 25, 'address': 'jaipur', 'city': 'jaipur'}

# %% [markdown]
# ### nested dict

# %%
data = {
    1:{'name':'deep', 'age':26, 'address':'jaipur'},
    2:{'name':'simran', 'age':27, 'address':'jaipur'},
    3:{'name':'sachin', 'age':29, 'address':'jaipur'},
    4:{'name':'rohan', 'age':28, 'address':'jaipur'}
}

# %%
data
# Out:
# {1: {'name': 'deep', 'age': 26, 'address': 'jaipur'},
#  2: {'name': 'simran', 'age': 27, 'address': 'jaipur'},
#  3: {'name': 'sachin', 'age': 29, 'address': 'jaipur'},
#  4: {'name': 'rohan', 'age': 28, 'address': 'jaipur'}}

# %%
len(data)
# Out:
# 4

# %%
data.keys()
# Out:
# dict_keys([1, 2, 3, 4])

# %%
data.values()
# Out:
# dict_values([{'name': 'deep', 'age': 26, 'address': 'jaipur'}, {'name': 'simran', 'age': 27, 'address': 'jaipur'}, {'name': 'sachin', 'age': 29, 'address': 'jaipur'}, {'name': 'rohan', 'age': 28, 'address': 'jaipur'}])

# %%
data
# Out:
# {1: {'name': 'deep', 'age': 26, 'address': 'jaipur'},
#  2: {'name': 'simran', 'age': 27, 'address': 'jaipur'},
#  3: {'name': 'sachin', 'age': 29, 'address': 'jaipur'},
#  4: {'name': 'rohan', 'age': 28, 'address': 'jaipur'}}

# %%
data[3]
# Out:
# {'name': 'sachin', 'age': 29, 'address': 'jaipur'}

# %%
data[3]['age']
# Out:
# 29

# %%
data
# Out:
# {1: {'name': 'deep', 'age': 26, 'address': 'jaipur'},
#  2: {'name': 'simran', 'age': 27, 'address': 'jaipur'},
#  3: {'name': 'sachin', 'age': 29, 'address': 'jaipur'},
#  4: {'name': 'rohan', 'age': 28, 'address': 'jaipur'}}

# %%
data[5] = {'name':'ram', 'age':22, 'address':'jaipur'}

# %%
data
# Out:
# {1: {'name': 'deep', 'age': 26, 'address': 'jaipur'},
#  2: {'name': 'simran', 'age': 27, 'address': 'jaipur'},
#  3: {'name': 'sachin', 'age': 29, 'address': 'jaipur'},
#  4: {'name': 'rohan', 'age': 28, 'address': 'jaipur'},
#  5: {'name': 'ram', 'age': 22, 'address': 'jaipur'}}

# %%
data[2]
# Out:
# {'name': 'simran', 'age': 27, 'address': 'jaipur'}

# %%
data[2]['city'] = 'jaipur'

# %%
data
# Out:
# {1: {'name': 'deep', 'age': 26, 'address': 'jaipur'},
#  2: {'name': 'simran', 'age': 27, 'address': 'jaipur', 'city': 'jaipur'},
#  3: {'name': 'sachin', 'age': 29, 'address': 'jaipur'},
#  4: {'name': 'rohan', 'age': 28, 'address': 'jaipur'},
#  5: {'name': 'ram', 'age': 22, 'address': 'jaipur'}}

# %%
data[3]['marks'] = {'math':45, 'physics':55, 'chem':23}

# %%
data
# Out:
# {1: {'name': 'deep', 'age': 26, 'address': 'jaipur'},
#  2: {'name': 'simran', 'age': 27, 'address': 'jaipur', 'city': 'jaipur'},
#  3: {'name': 'sachin',
#   'age': 29,
#   'address': 'jaipur',
#   'marks': {'math': 45, 'physics': 55, 'chem': 23}},
#  4: {'name': 'rohan', 'age': 28, 'address': 'jaipur'},
#  5: {'name': 'ram', 'age': 22, 'address': 'jaipur'}}

# %%
data[3]['marks']['chem'] = 50

# %%
data
# Out:
# {1: {'name': 'deep', 'age': 26, 'address': 'jaipur'},
#  2: {'name': 'simran', 'age': 27, 'address': 'jaipur', 'city': 'jaipur'},
#  3: {'name': 'sachin',
#   'age': 29,
#   'address': 'jaipur',
#   'marks': {'math': 45, 'physics': 55, 'chem': 50}},
#  4: {'name': 'rohan', 'age': 28, 'address': 'jaipur'},
#  5: {'name': 'ram', 'age': 22, 'address': 'jaipur'}}

# %%
v = data[3].popitem()
v
# Out:
# ('marks', {'math': 45, 'physics': 55, 'chem': 50})

# %%
data
# Out:
# {1: {'name': 'deep', 'age': 26, 'address': 'jaipur'},
#  2: {'name': 'simran', 'age': 27, 'address': 'jaipur', 'city': 'jaipur'},
#  3: {'name': 'sachin', 'age': 29, 'address': 'jaipur'},
#  4: {'name': 'rohan', 'age': 28, 'address': 'jaipur'},
#  5: {'name': 'ram', 'age': 22, 'address': 'jaipur'}}

# %%
data[v[0]] = v[1]

# %%
data
# Out:
# {1: {'name': 'deep', 'age': 26, 'address': 'jaipur'},
#  2: {'name': 'simran', 'age': 27, 'address': 'jaipur', 'city': 'jaipur'},
#  3: {'name': 'sachin', 'age': 29, 'address': 'jaipur'},
#  4: {'name': 'rohan', 'age': 28, 'address': 'jaipur'},
#  5: {'name': 'ram', 'age': 22, 'address': 'jaipur'},
#  'marks': {'math': 45, 'physics': 55, 'chem': 50}}

# %%
data[3]['marks'] = [34,56,78]

# %%
data
# Out:
# {1: {'name': 'deep', 'age': 26, 'address': 'jaipur'},
#  2: {'name': 'simran', 'age': 27, 'address': 'jaipur', 'city': 'jaipur'},
#  3: {'name': 'sachin', 'age': 29, 'address': 'jaipur', 'marks': [34, 56, 78]},
#  4: {'name': 'rohan', 'age': 28, 'address': 'jaipur'},
#  5: {'name': 'ram', 'age': 22, 'address': 'jaipur'},
#  'marks': {'math': 45, 'physics': 55, 'chem': 50}}

# %%
data[3]['marks'].append(70)

# %%
data
# Out:
# {1: {'name': 'deep', 'age': 26, 'address': 'jaipur'},
#  2: {'name': 'simran', 'age': 27, 'address': 'jaipur', 'city': 'jaipur'},
#  3: {'name': 'sachin',
#   'age': 29,
#   'address': 'jaipur',
#   'marks': [34, 56, 78, 70]},
#  4: {'name': 'rohan', 'age': 28, 'address': 'jaipur'},
#  5: {'name': 'ram', 'age': 22, 'address': 'jaipur'},
#  'marks': {'math': 45, 'physics': 55, 'chem': 50}}

# %% [markdown]
# ### Set
#
#         collection of unique elements
#         { }
#         unordered
#         mutable

# %%
s = {34,567,789,34,78,23,67,89,45,89,34,89}

# %%
s
# Out:
# {23, 34, 45, 67, 78, 89, 567, 789}

# %%
s[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 s[0]
#
# TypeError: 'set' object is not subscriptable

# %%
print([i for i in dir(set) if not i.startswith('__')])
# Out:
# ['add', 'clear', 'copy', 'difference', 'difference_update', 'discard', 'intersection', 'intersection_update', 'isdisjoint', 'issubset', 'issuperset', 'pop', 'remove', 'symmetric_difference', 'symmetric_difference_update', 'union', 'update']

# %%
s
# Out:
# {23, 34, 45, 67, 78, 89, 567, 789}

# %%
s.add(100)

# %%
s
# Out:
# {23, 34, 45, 67, 78, 89, 100, 567, 789}

# %%
s.add(-100)

# %%
s
# Out:
# {-100, 23, 34, 45, 67, 78, 89, 100, 567, 789}

# %%
print(s)
# Out:
# {34, 67, 100, 45, 78, 23, 789, 567, 89, -100}

# %%
s.add(67)

# %%
s
# Out:
# {-100, 23, 34, 45, 67, 78, 89, 100, 567, 789}

# %%
s.update([10,20,30,40,50])

# %%
s
# Out:
# {-100, 10, 20, 23, 30, 34, 40, 45, 50, 67, 78, 89, 100, 567, 789}

# %%
print(s)
# Out:
# {34, 67, 100, 40, 10, 45, 78, 50, 23, 789, 20, 567, 89, -100, 30}

# %% [markdown]
#     remove
#     pop
#     discard
#     clear

# %%
s.remove(100)

# %%
s
# Out:
# {-100, 10, 20, 23, 30, 34, 40, 45, 50, 67, 78, 89, 567, 789}

# %%
s.pop()
# Out:
# 34

# %%
s
# Out:
# {-100, 10, 20, 23, 30, 40, 45, 50, 67, 78, 89, 567, 789}

# %%
s.pop()
# Out:
# 67

# %%
s.remove(100)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 s.remove(100)
#
# KeyError: 100

# %%
s.discard(100)

# %%
s
# Out:
# {-100, 10, 20, 23, 30, 40, 45, 50, 78, 89, 567, 789}

# %%
s.discard(10)

# %%
s
# Out:
# {-100, 20, 23, 30, 40, 45, 50, 78, 89, 567, 789}

# %%
s1 = {23,45,67}
s2 = {12,45,67,34,23}

# %%
s1.union(s2)
# Out:
# {12, 23, 34, 45, 67}

# %%
s1.intersection(s2)
# Out:
# {23, 45, 67}

# %%
s1
# Out:
# {23, 45, 67}

# %%
s2
# Out:
# {12, 23, 34, 45, 67}

# %%
s1.difference(s2)
# Out:
# set()

# %%
s2.difference(s1)
# Out:
# {12, 34}

# %%
s1
# Out:
# {23, 45, 67}

# %%
s2
# Out:
# {12, 23, 34, 45, 67}

# %%
s1.issubset(s2)
# Out:
# True

# %%
s1.issuperset(s2)
# Out:
# False

# %%
s2.issuperset(s1)
# Out:
# True

# %%
data = {'fsq_place_id': '66ffe361afe465645a44bd74',
 'latitude': 26.950881,
 'longitude': 75.704488,
 'categories': [{'fsq_category_id': '4bf58dd8d48988d106951735',
   'name': "Men's Store",
   'short_name': "Men's Store",
   'plural_name': "Men's Stores",
   'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_men_',
    'suffix': '.png'}}],
 'date_created': '2024-10-04',
 'date_refreshed': '2024-10-04',
 'distance': 622,
 'extended_location': {},
 'link': '/places/66ffe361afe465645a44bd74',
 'location': {'address': 'Shop No 6 & 7, SS Tower,Krishna Market, Kalwar Road',
  'locality': 'Jaipur',
  'region': 'Rājasthān',
  'postcode': '302012',
  'country': 'IN',
  'formatted_address': 'Shop No 6 & 7, SS Tower,Krishna Market, Kalwar Road (Govindpura), Jaipur 302012, Rājasthān'},
 'name': 'John Players',
 'placemaker_url': 'https://foursquare.com/placemakers/review-place/66ffe361afe465645a44bd74',
 'related_places': {},
 'social_media': {'twitter': ''},
 'tel': '096368 30800',
 'website': 'https://johnplayerstores.com/john-players-men-s-clothes-shop-govindpura-jaipur-302570/Home'}

# %%
data
# Out:
# {'fsq_place_id': '66ffe361afe465645a44bd74',
#  'latitude': 26.950881,
#  'longitude': 75.704488,
#  'categories': [{'fsq_category_id': '4bf58dd8d48988d106951735',
#    'name': "Men's Store",
#    'short_name': "Men's Store",
#    'plural_name': "Men's Stores",
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_men_',
#     'suffix': '.png'}}],
#  'date_created': '2024-10-04',
#  'date_refreshed': '2024-10-04',
#  'distance': 622,
#  'extended_location': {},
#  'link': '/places/66ffe361afe465645a44bd74',
#  'location': {'address': 'Shop No 6 & 7, SS Tower,Krishna Market, Kalwar Road',
#   'locality': 'Jaipur',
#   'region': 'Rājasthān',
#   'postcode': '302012',
#   'country': 'IN',
#   'formatted_address': 'Shop No 6 & 7, SS Tower,Krishna Market, Kalwar Road (Govindpura), Jaipur 302012, Rājasthān'},
#  'name': 'John Players',
#  'placemaker_url': 'https://foursquare.com/placemakers/review-place/66ffe361afe465645a44bd74',
#  'related_places': {},
# ...

# %% [markdown]
# # Operators
# 1. Arithmetical operator
# 2. Assignment Operator
# 3. Comparison Operator
# 4. Logical Operator
# 5. Membership Operator
# 6. Identity Operator
# 7. Bitwise Operator

# %% [markdown]
# ### Arithmetical Operator
#
#             +  -  *  /   %  //  **

# %%
a = 10
b = 20
c = 23

# %%
print(a+b)
print(a-b)
print(a*b)
# Out:
# 30
# -10
# 200

# %%
b / a
# Out:
# 2.0

# %%
20 % 3
# Out:
# 2

# %%
20 % 10
# Out:
# 0

# %%
20 / 3
# Out:
# 6.666666666666667

# %%
20 // 3
# Out:
# 6

# %%
20 // 3.0
# Out:
# 6.0

# %%
-20 // 3
# Out:
# -7

# %%
2**3
# Out:
# 8

# %% [markdown]
# ### assignment
#
#             =  +=  -=  *=  /=

# %%
name = 'harsh'
name
# Out:
# 'harsh'

# %%
a
# Out:
# 10

# %%
b
# Out:
# 20

# %%
a = a + b

# %%
a
# Out:
# 30

# %%
a += b

# %%
a
# Out:
# 50

# %%
b
# Out:
# 20

# %%
b -= a

# %%
b
# Out:
# -30

# %% [markdown]
# ### Comparison operator
#                         <   >   <=   >=  ==  !=

# %%
a
# Out:
# 50

# %%
b
# Out:
# -30

# %%
c
# Out:
# 23

# %%
a < b
# Out:
# False

# %%
a > b
# Out:
# True

# %%
a
# Out:
# 50

# %%
c
# Out:
# 23

# %%
b
# Out:
# -30

# %%
a == c
# Out:
# False

# %%
a != b
# Out:
# True

# %% [markdown]
# ### Logical operator
#
#                         1. Logical and
#                         2. Logical or
#                         3. Logical not

# %%
a
# Out:
# 50

# %%
b
# Out:
# -30

# %%
c
# Out:
# 23

# %%
a < b and b == a
# Out:
# False

# %%
a > b and b < c
# Out:
# True

# %%
a < b or b < a
# Out:
# True

# %%
not(a < b or b < a)
# Out:
# False

# %% [markdown]
# ### Membership
#
#             1. in
#             2. not in

# %%
lst = [23,45,67,78,45,67]

# %%
100 in lst
# Out:
# False

# %%
23 in lst
# Out:
# True

# %% [markdown]
# ### Identity operator
#                         1. is
#                         2. is not

# %%
a = 270
b = 270

# %%
a == b
# Out:
# True

# %%
a is b
# Out:
# False

# %%
i = 200
j = 200

# %%
i == j
# Out:
# True

# %%
i is j
# Out:
# True

# %% [markdown]
# ### Bitwise Operator
#
#         bitwise &
#         bitwise |
#         bitwise ~
#         XOR   ^
#         left shift
#         right shift

# %%
12 & 13
# Out:
# 12

# %%
12 | 13
# Out:
# 13

# %%
12^13
# Out:
# 1

# %%
4 << 2
# Out:
# 16

# %%
8 >> 2
# Out:
# 2

# %%
8 >> 3
# Out:
# 1

# %%
8 >> 4
# Out:
# 0
