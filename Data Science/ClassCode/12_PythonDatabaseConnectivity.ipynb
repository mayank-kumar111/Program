# %% [markdown]
#     pip install pymysql

# %%
import pymysql as sql

# %%
conn = sql.connect(user='root', password='', port=3306, host='localhost', database="dsml_internship")
conn

# %%
conn

# %%
show databases;
# Out:
#   Cell In[6], line 1
#     show databases;
#          ^
# SyntaxError: invalid syntax

# %%
cur = conn.cursor()
cur

# %%
cur.execute("show databases")
# Out:
# 6

# %%
cur.fetchall()
# Out:
# (('dsml_internship',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('phpmyadmin',),
#  ('test',))

# %%
cur.execute("show tables")
cur.fetchall()
# Out:
# (('address',), ('fees',), ('new',), ('student',))

# %%
conn.close()

# %%
def connect_db():
    conn = sql.connect(user='root', password='', port=3306, host='localhost', database="dsml_internship")
    cur = conn.cursor()
    return conn, cur

# %%
conn, cur = connect_db()

# %%
conn

# %%
cur

# %%
cur.execute("select * from student")
cur.fetchall()
# Out:
# ((101, 'aman', 23),
#  (102, 'rohan', 25),
#  (103, 'deep', 26),
#  (104, 'gaurav', 21),
#  (105, 'ram', 21),
#  (106, 'himanshu', 23),
#  (107, 'rajesh', 22))

# %%
cur.execute("insert into student values(108, 'rajat', 25)")
# Out:
# 1

# %%
conn.commit()

# %%
conn.close()
