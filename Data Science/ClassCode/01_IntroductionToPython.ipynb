# %%
print("Hello world")
# Out:
# Hello world

# %%
hello we are learning python programming
# Out:
#   Cell In[2], line 1
#     hello we are learning python programming
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# we are learning python

# %% [markdown]
#     .py
#     .ipynb

# %% [markdown]
# # This is 1st level heading
# ## This is 2nd level heading
# ### This is 3rd level heading
# #### 4th level
# ##### 5th level
# ###### 6th level

# %% [markdown]
# # Introduction to Python Programming
# - Data types
# - operators
# - Control Flow
# - Functions
# - OOPS
# - File Handling
# - Exception Handling

# %% [markdown]
# #### Data types
# 1. Numbers
# 2. Str
# 3. List
# 4. Tuple
# 5. Dict
# 6. Set
# 7. Bool
# 8. None

# %% [markdown]
#     Numbers
#                 1. int        --> complete numbers   23, 45,-78
#                 2. float      --> incomplete numbers   -4.5, 5.6
#                 3. complex    --> real + imag      3 + 2j
#                                                    -3.3 + 4j

# %% [markdown]
#     Str
#             Collection of characters
#             ' '
#             " "
#             """ """
#             ordered
#             immutable

# %%
name = "harsh"
print(name)
# Out:
# harsh

# %%
v = 'rohan's car'
print(v)
# Out:
#   Cell In[4], line 1
#     v = 'rohan's car'
#                     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
v = "rohan's car"
print(v)
# Out:
# rohan's car

# %%
print(2+4)
# Out:
# 6

# %% [markdown]
#     List
#             collection of objects
#             [ ]
#             ordered
#             mutable

# %%
names = ['deep', 'himanshu', 'naman', 'sagar', 'simran']

# %%
print(names)
# Out:
# ['deep', 'himanshu', 'naman', 'sagar', 'simran']

# %%
data = [23,5.5, 'python', 'hello']

# %%
print(data)
# Out:
# [23, 5.5, 'python', 'hello']

# %% [markdown]
#     Tuple
#             collection of objects
#             ( )
#             ordered
#             immutable

# %%
t = (23,56,67,78,45,78)

# %%
print(t)
# Out:
# (23, 56, 67, 78, 45, 78)

# %%
d = (23,4.4, 4+3j, 'hello world')

# %%
print(d)
# Out:
# (23, 4.4, (4+3j), 'hello world')

# %%
age = (34)

# %%
print(age)
# Out:
# 34

# %% [markdown]
#     dict
#
#         collection of key & value pairs
#         { }
#         unordered   ---> before python 3.6
#         ordered     ---> after python 3.6
#         mutable
#         keys must be unique & immutable

# %%
data = {'name':'deep', 'age':26, 'address':'jaipur'}
print(data)
# Out:
# {'name': 'deep', 'age': 26, 'address': 'jaipur'}

# %% [markdown]
#     set
#         collection of unique values
#         { }
#         unordered
#         mutable

# %%
s = {23,45,56,23,56,78,34,67,78}

# %%
print(s)
# Out:
# {34, 67, 23, 56, 45, 78}

# %% [markdown]
#     bool
#             True
#             False

# %%
a = True
b = False

# %%
print(a)
# Out:
# True

# %%
print(b)
# Out:
# False

# %% [markdown]
# ## Variables

# %% [markdown]
# Rules:
# 1. variable name should contain a-z, A-Z, _
# 2. variable name can not start with number but it can end with
# 3. variable name can not contain white sapce & special characters
# 4. variable name can not be same as keywords & built-in functions

# %%
name = "deep"

# %%
1name = "deep"
2name = 'simran'
3name = 'sachin'
# Out:
#   Cell In[24], line 1
#     1name = "deep"
#     ^
# SyntaxError: invalid decimal literal

# %%
name1 = "deep"
name2 = 'simran'
name3 = 'sachin'

# %%
print(name1)
# Out:
# deep

# %%
print(name2)
# Out:
# simran

# %%
your name = "rohan"
# Out:
#   Cell In[28], line 1
#     your name = "rohan"
#          ^
# SyntaxError: invalid syntax

# %%
your_name = "rohan"

# %%
your_name
# Out:
# 'rohan'

# %%
name& = "aman"
# Out:
#   Cell In[31], line 1
#     name& = "aman"
#           ^
# SyntaxError: invalid syntax

# %%
from keyword import kwlist

# %%
print(kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
if = "hello"
# Out:
#   Cell In[34], line 1
#     if = "hello"
#        ^
# SyntaxError: invalid syntax

# %%
print("hello world")
# Out:
# hello world

# %%
print = "hello world"

# %%
print
# Out:
# 'hello world'

# %%
print("python is awesome")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 print("python is awesome")
#
# TypeError: 'str' object is not callable

# %%
print("python is awesome")
# Out:
# python is awesome
