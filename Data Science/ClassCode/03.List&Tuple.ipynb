# %% [markdown]
# # List
#
#             collection of objects
#             [ ]
#             mutable
#             ordered

# %%
print([i for i in dir(list)  if not i.startswith('__')])
# Out:
# ['append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
lst = [23,45,67,78,45,78,33]
lst
# Out:
# [23, 45, 67, 78, 45, 78, 33]

# %%
lst[0]
# Out:
# 23

# %%
lst[0] = 100

# %%
lst
# Out:
# [100, 45, 67, 78, 45, 78, 33]

# %% [markdown]
#     add element in list
#
#             append
#             extend
#             insert

# %%
lst
# Out:
# [100, 45, 67, 78, 45, 78, 33]

# %%
lst.append(100)

# %%
lst
# Out:
# [100, 45, 67, 78, 45, 78, 33, 100]

# %%
lst.extend([10,20,30,40])

# %%
lst
# Out:
# [100, 45, 67, 78, 45, 78, 33, 100, 10, 20, 30, 40]

# %%
lst
# Out:
# [100, 45, 67, 78, 45, 78, 33, 100, 10, 20, 30, 40]

# %%
lst.append(['python', 'java', 'c++'])

# %%
lst
# Out:
# [100, 45, 67, 78, 45, 78, 33, 100, 10, 20, 30, 40, ['python', 'java', 'c++']]

# %%
data = [10,20,30,40,50]

# %%
data
# Out:
# [10, 20, 30, 40, 50]

# %%
data.insert(1, 100)

# %%
data
# Out:
# [10, 100, 20, 30, 40, 50]

# %% [markdown]
#     removing elements
#
#     remove
#     pop
#     clear

# %%
lst
# Out:
# [100, 45, 67, 78, 45, 78, 33, 100, 10, 20, 30, 40, ['python', 'java', 'c++']]

# %%
lst.remove(45)

# %%
lst
# Out:
# [100, 67, 78, 45, 78, 33, 100, 10, 20, 30, 40, ['python', 'java', 'c++']]

# %% [markdown]
#     lst.remove(100)

# %%
lst.pop(6)
# Out:
# 100

# %%
lst
# Out:
# [100, 67, 78, 45, 78, 33, 10, 20, 30, 40, ['python', 'java', 'c++']]

# %%
lst.pop()
# Out:
# ['python', 'java', 'c++']

# %%
lst
# Out:
# [100, 67, 78, 45, 78, 33, 10, 20, 30, 40]

# %%
data
# Out:
# [10, 100, 20, 30, 40, 50]

# %%
data.clear()

# %%
data
# Out:
# []

# %%
data.remove(100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 data.remove(100)
#
# ValueError: list.remove(x): x not in list

# %%
lst
# Out:
# [100, 67, 78, 45, 78, 33, 10, 20, 30, 40]

# %%
lst.extend([100,45,78,78])

# %%
lst
# Out:
# [100, 67, 78, 45, 78, 33, 10, 20, 30, 40, 100, 45, 78, 78]

# %%
lst.count(100)
# Out:
# 2

# %%
lst.count(78)
# Out:
# 4

# %%
lst
# Out:
# [100, 67, 78, 45, 78, 33, 10, 20, 30, 40, 100, 45, 78, 78]

# %%
lst.index(100)
# Out:
# 0

# %%
lst.index(67)
# Out:
# 1

# %%
lst.index(100, 1)
# Out:
# 10

# %%
lst
# Out:
# [100, 67, 78, 45, 78, 33, 10, 20, 30, 40, 100, 45, 78, 78]

# %%
lst.reverse()

# %%
lst
# Out:
# [78, 78, 45, 100, 40, 30, 20, 10, 33, 78, 45, 78, 67, 100]

# %%
lst.sort()

# %%
lst
# Out:
# [10, 20, 30, 33, 40, 45, 45, 67, 78, 78, 78, 78, 100, 100]

# %%
v = [78, 78, 45, 100, 40, 30, 20, 10, 33, 78, 45, 78, 67, 100]
v
# Out:
# [78, 78, 45, 100, 40, 30, 20, 10, 33, 78, 45, 78, 67, 100]

# %%
lst.sort(reverse=True)

# %%
lst
# Out:
# [100, 100, 78, 78, 78, 78, 67, 45, 45, 40, 33, 30, 20, 10]

# %%
lst
# Out:
# [100, 100, 78, 78, 78, 78, 67, 45, 45, 40, 33, 30, 20, 10]

# %%
new = lst.copy()
new
# Out:
# [100, 100, 78, 78, 78, 78, 67, 45, 45, 40, 33, 30, 20, 10]

# %%
id(lst)
# Out:
# 2442512469440

# %%
id(new)
# Out:
# 2442532566208

# %%
a = 100
b = 100

# %%
id(a)
# Out:
# 140728095461256

# %%
id(b)
# Out:
# 140728095461256

# %%
i = 210
j = 210

# %%
id(i)
# Out:
# 140728095464776

# %%
id(j)
# Out:
# 140728095464776

# %%
a = 257
b = 257

# %%
id(a)
# Out:
# 2442519371568

# %%
id(b)
# Out:
# 2442519370736

# %% [markdown]
# # nested list
