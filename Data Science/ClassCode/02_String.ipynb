# %% [markdown]
# # String
#             collection of characters
#             ' '
#             " "
#             """ """
#             ordered
#             immutable

# %%
print([i for i in dir(str) if not i.startswith('__')])
# Out:
# ['capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
s1 = "python is awesome"

# %%
s1
# Out:
# 'python is awesome'

# %%
print(type(s1))
# Out:
# <class 'str'>

# %%
s1
# Out:
# 'python is awesome'

# %%
s1.upper()
# Out:
# 'PYTHON IS AWESOME'

# %%
s1
# Out:
# 'python is awesome'

# %%
s2 = s1.upper()
print(s2)
# Out:
# PYTHON IS AWESOME

# %%
s2
# Out:
# 'PYTHON IS AWESOME'

# %%
s1
# Out:
# 'python is awesome'

# %%
s = "pYtHoN"

# %%
s
# Out:
# 'pYtHoN'

# %%
s.swapcase()
# Out:
# 'PyThOn'

# %%
s = "we are learning python"

# %%
s
# Out:
# 'we are learning python'

# %%
s.split()
# Out:
# ['we', 'are', 'learning', 'python']

# %%
s
# Out:
# 'we are learning python'

# %%
s.split("a")
# Out:
# ['we ', 're le', 'rning python']

# %%
lst = ['S', 'A', 'C', 'H', 'I', 'N']

# %%
lst
# Out:
# ['S', 'A', 'C', 'H', 'I', 'N']

# %%
"-".join(lst)
# Out:
# 'S-A-C-H-I-N'

# %%
"".join(lst)
# Out:
# 'SACHIN'

# %%
" ".join(lst)
# Out:
# 'S A C H I N'

# %% [markdown]
#     validation methods
#
#             isupper
#             islower
#             isdigit
#             isspace
#             isalpha
#             isalnum
#             .
#             .
#             .

# %%
s
# Out:
# 'we are learning python'

# %%
s.isupper()
# Out:
# False

# %%
s.islower()
# Out:
# True

# %%
s1
# Out:
# 'python is awesome'

# %%
s2
# Out:
# 'PYTHON IS AWESOME'

# %%
s2.isupper()
# Out:
# True

# %%
v = "456456"

# %%
v
# Out:
# '456456'

# %%
v.isdigit()
# Out:
# True

# %%
s
# Out:
# 'we are learning python'

# %%
s.isalpha()
# Out:
# False

# %%
"helloworld".isalpha()
# Out:
# True

# %%
"python3".isalpha()
# Out:
# False

# %%
"python3".isalnum()
# Out:
# True

# %%
v
# Out:
# '456456'

# %%
v.isdigit()
# Out:
# True

# %%
v.isnumeric()
# Out:
# True

# %%
s1
# Out:
# 'python is awesome'

# %%
s1.startswith("p")
# Out:
# True

# %%
s1.startswith("python")
# Out:
# True

# %%
s1.startswith("Python")
# Out:
# False

# %%
s1
# Out:
# 'python is awesome'

# %%
s1.endswith("me")
# Out:
# True

# %%
s1
# Out:
# 'python is awesome'

# %% [markdown]
# #### indexing

# %%
s
# Out:
# 'we are learning python'

# %%
s[0]
# Out:
# 'w'

# %%
s[4]
# Out:
# 'r'

# %%
s[-2]
# Out:
# 'o'

# %%
lst = [23,56,67,89,56,78,8956]

# %%
len(lst)
# Out:
# 7

# %%
lst[-3]
# Out:
# 56

# %%
lst[2]
# Out:
# 67

# %%
tp = (23,56,78,45,78)

# %%
tp[-2]
# Out:
# 45

# %%
lst
# Out:
# [23, 56, 67, 89, 56, 78, 8956]

# %%
lst[0]
# Out:
# 23

# %%
lst[0] = 100

# %%
lst
# Out:
# [100, 56, 67, 89, 56, 78, 8956]

# %%
lst[0]
# Out:
# 100

# %%
s
# Out:
# 'we are learning python'

# %%
s[0]
# Out:
# 'w'

# %%
s[0] = 'W'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 s[0] = 'W'
#
# TypeError: 'str' object does not support item assignment

# %%
tp
# Out:
# (23, 56, 78, 45, 78)

# %%
tp[0] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 tp[0] = 100
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
#     mutable     immutable
#     list           numbers
#     dict           str
#     set            tuple

# %%
s1
# Out:
# 'python is awesome'

# %%
s1.index("p")
# Out:
# 0

# %%
s1.index("o")
# Out:
# 4

# %%
s1.rindex("o")
# Out:
# 14

# %%
s1
# Out:
# 'python is awesome'

# %%
s1.center(100)
# Out:
# '                                         python is awesome                                          '

# %%
s1.center(100, '-')
# Out:
# '-----------------------------------------python is awesome------------------------------------------'

# %%
s1.ljust(100, '*')
# Out:
# 'python is awesome***********************************************************************************'

# %%
s1.rjust(100, '*')
# Out:
# '***********************************************************************************python is awesome'

# %% [markdown]
#     f string

# %%
name = input("Enter name: ")
age = int(input("Enter age: "))
print("hello", name, ". You are", age, "years old")
# Out:
# Enter name:  deep
# Enter age:  26
# hello deep . You are 26 years old

# %% [markdown]
#     Hello {name}. You are {age} years old.

# %%
name = input("Enter name: ")
age = int(input("Enter age: "))
print(f"hello {name}, You are {age} years old.")
# Out:
# Enter name:  deep
# Enter age:  26
# hello deep, You are 26 years old.

# %%
name = input("Enter name: ")
age = int(input("Enter age: "))
print("hello {}, You are {} years old.".format(name,age))
# Out:
# Enter name:  aman
# Enter age:  23
# hello aman, You are 23 years old.
