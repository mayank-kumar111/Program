# %%
import requests

url = "https://example.com/music.mp3"  # Replace with actual MP3 URL

response = requests.get(url)
data = response.content

file = open("1_music.mp3", "wb")
file.write(data)
file.close()

print("Music downloaded successfully!")

# %%
import requests

url = "https://example.com/music.mp3"  # Replace with actual MP3 URL
filename = "2_music.mp3"

response = requests.get(url)

with open(filename, "wb") as file:
    file.write(response.content)

print("Music downloaded successfully!")

# %%
import requests
from tqdm import tqdm

# tqdm is a library for showing progress bars in Python.

url = "https://www.soundhelix.com/examples/mp3/SoundHelix-Song-1.mp3"
filename = "3_music.mp3"

response = requests.get(url, stream=True)

total_size = int(response.headers.get('content-length', 0))

with open(filename, "wb") as file:
    for data in tqdm(
        response.iter_content(chunk_size=1024),
        total=total_size // 1024,
        unit="KB"
    ):
        file.write(data)

print("Download completed!")
# Out:
# 8736KB [00:05, 1622.20KB/s]
# Download completed!
